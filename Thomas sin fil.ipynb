# %%
print("i")

print('Hello Thomas')
# Out:
# i
# Hello Thomas

# %%
print('hva skjer om vi endrer ting samtidig daaaa')
# Out:
# hva skjer om vi endrer ting samtidig daaaa

# %%
print("Vi endrer ting igjen. det er den 17. feb")
# Out:
# Vi endrer ting igjen. det er den 17. feb
