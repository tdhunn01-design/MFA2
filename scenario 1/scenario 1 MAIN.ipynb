# %%
#Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.optimize import curve_fit
from scipy.interpolate import CubicSpline
import os
import natural_cubic_spline_stack_overflow as ncs # taken from stack overflow
import csv
import dynamic_stock_model
from dynamic_stock_model import DynamicStockModel

# %% [markdown]
# STEP 1: POPULATION

# %%
# Extracting data from the source file into a panda Dataframe
file = "pop_data-scenario 1.xlsx"
# This file should be placed in the same directory as this notebook (on the JupyterHub server)

# We read the data and store it in a Dataframe called "data", using the read_excel() panda function
data = pd.read_excel(file, index_col = None, header = 0, usecols = 'A:H')

#print(data)

# %%
# collected the data in a single list to be able to plot it and use it for regression
data_col = pd.read_excel('pop_collection.xlsx', index_col = None, header = 0, usecols = 'A:B')
print(data_col)
# Out:
#      POPULATION  YEAR
# 0    33127478.5  2100
# 1    33302992.0  2099
# 2    33475731.5  2098
# 3    33645991.5  2097
# 4    33811182.5  2096
# ..          ...   ...
# 172   9536161.0  1730
# 173   9278427.0  1720
# 174   9027659.0  1710
# 175   8000000.0  1700
# 176   8500000.0  1600
#
# [177 rows x 2 columns]

# %%
plt.figure(figsize=(16,10))
plt.plot(data_col['YEAR'], data_col['POPULATION'], 'o-', color = 'black', label = f'population data chosen value')
plt.plot(data["TIME"], data["HYDE DATA"], '.', label="dataset way back", color='red')
plt.plot(data["TIME"], data["1900s POPULATION"], '.', label="dataset 1900s", color = 'mediumorchid')
plt.plot(data["TIME"], data["JAN POPULATION"], '.', label="dataset january", color = 'blueviolet')
plt.plot(data["TIME"], data["UN pred"], '.', label="UN prediction 2100", color = 'dodgerblue')
plt.grid()
plt.legend(loc = 'best', fontsize = 20)
plt.xticks(list(range(1600, 2101, 25)))
plt.xlabel('Years', fontsize = 20)
plt.ylabel('Population', fontsize = 20)
plt.title('Population data collection', fontsize = 25)
plt.ylim(ymin=0)
plt.show()

# %%
# natural cubic spline seems a better fit to account for population decline in the future
inputs = data_col['YEAR']
outputs = data_col['POPULATION']
pred_inputs = np.array(range(1600, 2101, 1))

# i choose the knots manually
knots = [1601, 1700, 1800, 1900, 1980, 2025, 2070, 2100]

# setting up the actual model (training)
ncs_model = ncs.get_natural_cubic_spline_model(inputs, outputs, knots = knots)

# predicting of the single curve by the model
pred_outputs = ncs_model.predict(pred_inputs)

#plot the knots:
plt.figure(figsize=(16,10))
i=1
for knot in knots:
    if i == 1:
        plt.plot([knot, knot], [min(pred_outputs), max(pred_outputs)], lw = 3, color = 'darkgreen', label = 'knots', alpha = 0.4)
        i +=1
    else:
        plt.plot([knot, knot], [min(pred_outputs), max(pred_outputs)], lw = 3, color = 'darkgreen', alpha = 0.4)

plt.plot(data_col['YEAR'], data_col['POPULATION'], 'o-', color = 'silver', label = f'population data chosen value')
plt.plot(pred_inputs, pred_outputs, color = 'maroon', lw = 3, alpha = 0.8, label = 'ncs regression values')
plt.legend(loc = 'best', fontsize = 20)
plt.xticks(list(range(1600, 2101, 25)))
plt.grid()
plt.xlabel('Years', fontsize = 20)
plt.ylabel('Values', fontsize = 20)
plt.title('Natural cubic spline regression vpc data set', fontsize = 25)
plt.ylim(ymin=0)
plt.show()


pred_inputs_ncs_p = pred_inputs
pred_outputs_ncs_p = pred_outputs
# Out:
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# making the data ready to export to csv by making an array and transposing it
exportdata = np.array([pred_inputs, pred_outputs])
exportdata = exportdata.T
print(exportdata.shape)
# Out:
# (501, 2)

# %%
# exporting to csv. finished :)
filename = 'population.csv'

# Open the file in write mode ('w') and use writerows()
with open(filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(exportdata)

print(f"Data successfully exported to {filename} using csv module.")
# Out:
# Data successfully exported to population.csv using csv module.

# %% [markdown]
# STEP 2: PERSONS PER DWELLING PPD

# %%
# =============================================================================
# 1. DATA LOADING AND PREPARATION
# =============================================================================
print('Loading data...')
df = pd.read_excel('PPD estimate.xlsx')
df.columns = ['Year', 'PPD']
df_clean = df.dropna(subset=['PPD'])
print(f"Loaded {len(df_clean)} data points")
# Out:
# Loading data...
# Loaded 8 data points

# %%
# =============================================================================
# 2. MODEL PARAMETERS
# =============================================================================
interp_start = 1850
interp_end = 2039

# Split data into within-range and outside-range
data_within_range = df_clean[(df_clean['Year'] >= interp_start) & (df_clean['Year'] <= interp_end)]
data_before = df_clean[df_clean['Year'] < interp_start]
data_after = df_clean[df_clean['Year'] > interp_end]

print(f"\n📊 Data summary:")
print(f"  Data points within {interp_start}-{interp_end}: {len(data_within_range)}")
print(f"  Data points before {interp_start}: {len(data_before)}")
print(f"  Data points after {interp_end}: {len(data_after)}")
# Out:
# 📊 Data summary:
#   Data points within 1850-2039: 8
#   Data points before 1850: 0
#   Data points after 2039: 0

# %%
# =============================================================================
# 3. CREATE INTERPOLATION MODEL (CUBIC SPLINE)
# =============================================================================
if len(data_within_range) >= 3:
    years_with_data = data_within_range['Year'].values
    ppd_with_data = data_within_range['PPD'].values
    cs = CubicSpline(years_with_data, ppd_with_data, bc_type='natural')
    print(f"✅ Cubic spline created using {len(data_within_range)} data points")
else:
    print("⚠️  Not enough data points for cubic spline")
    cs = None
# Out:
# ✅ Cubic spline created using 8 data points

# %%
# =============================================================================
# 4. CREATE EXTRAPOLATION MODELS (LINEAR TRENDS)
# =============================================================================
# Backward trend: from 5.0 in 1850 to 6.0 in 1600
slope_backward = (5.0 - 6.0) / (1850 - 1600)  # = -1.0 / 250 = -0.004
intercept_backward = 5.0 - slope_backward * 1850

# Forward trend: from 2.32 in 2039 to 1.9 in 2100
slope_forward = (1.9 - 2.32) / (2100 - 2039)  # = -0.42 / 61 = -0.006885
intercept_forward = 2.32 - slope_forward * 2039

print(f"\n📐 Linear trend equations:")
print(f"  Backward (1600-1850): PPD = {slope_backward:.6f} × Year + {intercept_backward:.2f}")
print(f"  Forward (2039-2100): PPD = {slope_forward:.6f} × Year + {intercept_forward:.2f}")
# Out:
# 📐 Linear trend equations:
#   Backward (1600-1850): PPD = -0.004000 × Year + 12.40
#   Forward (2039-2100): PPD = -0.006885 × Year + 16.36

# %%
# =============================================================================
# 5. GENERATE PROJECTIONS FOR ALL YEARS
# =============================================================================
print(f"\n⏳ Generating projections for 1600-2100...")
all_years = np.arange(1600, 2101, 1)
ppd_combined = np.zeros_like(all_years, dtype=float)

for i, year in enumerate(all_years):
    if interp_start <= year <= interp_end and cs is not None:
        ppd_combined[i] = cs(year)  # Interpolation
    elif year < interp_start:
        ppd_combined[i] = slope_backward * year + intercept_backward  # Backward extrapolation
    else:  # year > interp_end
        ppd_combined[i] = slope_forward * year + intercept_forward  # Forward extrapolation

print(f"✅ Generated {len(all_years)} projections (years {all_years.min()}-{all_years.max()})")
# Out:
# ⏳ Generating projections for 1600-2100...
# ✅ Generated 501 projections (years 1600-2100)

# %%
# =============================================================================
# 6. SAVE PROJECTIONS TO CSV (DO THIS EARLY TO ENSURE DATA IS SAVED)
# =============================================================================
print(f"\n💾 Saving projections to CSV...")
projected_df = pd.DataFrame({
    'Year': all_years,
    'PPD_Projected': ppd_combined,
    'Method': ['Linear (backward)' if y < interp_start else 
               'Linear (forward)' if y > interp_end else 
               'Cubic Spline' for y in all_years]
})

output_file = 'spain_ppd_projections_1600_2100.csv'
projected_df.to_csv(output_file, index=False)
print(f"✅ Projections saved to '{output_file}'")
print(f"📊 File contains {len(projected_df)} rows")

# Show sample of saved data
print("\n📋 Sample of saved data (first 5 rows):")
print(projected_df.head())
print("\n📋 Sample of saved data (last 5 rows):")
print(projected_df.tail())
# Out:
# 💾 Saving projections to CSV...
# ✅ Projections saved to 'spain_ppd_projections_1600_2100.csv'
# 📊 File contains 501 rows
#
# 📋 Sample of saved data (first 5 rows):
#    Year  PPD_Projected             Method
# 0  1600          6.000  Linear (backward)
# 1  1601          5.996  Linear (backward)
# 2  1602          5.992  Linear (backward)
# 3  1603          5.988  Linear (backward)
# 4  1604          5.984  Linear (backward)
#
# 📋 Sample of saved data (last 5 rows):
#      Year  PPD_Projected            Method
# 496  2096       1.927541  Linear (forward)
# 497  2097       1.920656  Linear (forward)
# 498  2098       1.913770  Linear (forward)
# 499  2099       1.906885  Linear (forward)
# 500  2100       1.900000  Linear (forward)

# %%
# =============================================================================
# 7. CREATE VISUALIZATION
# =============================================================================
print(f"\n🎨 Creating plot...")
plt.figure(figsize=(15, 8))

# Original data points
plt.scatter(df_clean['Year'], df_clean['PPD'], 
           color='blue', s=60, alpha=0.8, label='Available PPD data', 
           zorder=4, edgecolors='white', linewidth=0.5)

# Combined curve
plt.plot(all_years, ppd_combined, 'r-', linewidth=2.5, 
         label='Combined model', alpha=0.9, zorder=2)

# Add vertical lines to mark the interpolation range
plt.axvline(x=interp_start, color='gray', linestyle='--', alpha=0.7, linewidth=1.5)
plt.axvline(x=interp_end, color='gray', linestyle='--', alpha=0.7, linewidth=1.5)

# Add horizontal lines for target values
plt.axhline(y=6.0, color='orange', linestyle=':', alpha=0.5, linewidth=1, label='Target: 6.0 in 1600')
plt.axhline(y=5.0, color='orange', linestyle=':', alpha=0.5, linewidth=1)
plt.axhline(y=2.32, color='green', linestyle=':', alpha=0.5, linewidth=1, label='Target: 2.32 in 2039')
plt.axhline(y=1.9, color='green', linestyle=':', alpha=0.5, linewidth=1, label='Target: 1.9 in 2100')

# Add text labels for the regions
plt.text(interp_start + 90, plt.ylim()[1] * 0.9, 
         'Cubic Spline\n(Interpolation 1850-2039)', 
         ha='center', fontsize=11, bbox=dict(boxstyle='round,pad=0.4', facecolor='yellow', alpha=0.4))
plt.text(1700, plt.ylim()[1] * 0.7, 
         'Linear Trend\n(1600-1850)\n6.0 → 5.0', 
         ha='center', fontsize=11, bbox=dict(boxstyle='round,pad=0.4', facecolor='lightblue', alpha=0.4))
plt.text(2070, plt.ylim()[1] * 0.7, 
         'Linear Trend\n(2039-2100)\n2.32 → 1.9', 
         ha='center', fontsize=11, bbox=dict(boxstyle='round,pad=0.4', facecolor='lightblue', alpha=0.4))

# Customize the plot
plt.title('Spain: Persons Per Dwelling (1600-2100)\nCubic Spline (1850-2039) + Custom Linear Trends', 
          fontsize=16, fontweight='bold')
plt.xlabel('Year', fontsize=12)
plt.ylabel('Persons Per Dwelling', fontsize=12)
plt.grid(True, alpha=0.3)
plt.legend(loc='lower left', fontsize=10)
plt.xlim(1600, 2100)

# Adjust y-axis limits
y_min = min(ppd_combined.min(), df_clean['PPD'].min(), 1.8) - 0.2
y_max = max(ppd_combined.max(), df_clean['PPD'].max(), 6.1) + 0.2
plt.ylim(y_min, y_max)

# Set x-ticks for key years
plt.xticks([1600, 1650, 1700, 1750, 1800, 1850, 1900, 1950, 2000, 2039, 2050, 2100], rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 🎨 Creating plot...

# %%
# =============================================================================
# 8. PRINT SUMMARY STATISTICS
# =============================================================================
print("\n📈 PROJECTIONS FOR KEY YEARS")
print("=" * 50)
key_years = [1600, 1650, 1700, 1750, 1800, 1850, 1900, 1950, 2000, 2039, 2050, 2075, 2100]
for year in key_years:
    if year in all_years:
        idx = np.where(all_years == year)[0][0]
        if year < interp_start:
            method = "Linear (backward)"
        elif year > interp_end:
            method = "Linear (forward)"
        else:
            method = "Cubic Spline"
        print(f"  Year {year}: {ppd_combined[idx]:.2f} PPD [{method}]")

# Target verification
print(f"\n✅ Target verification:")
print(f"  1600: {ppd_combined[1600-1600]:.2f} PPD (target: 6.0)")
print(f"  1850: {ppd_combined[1850-1600]:.2f} PPD (target: 5.0)")
print(f"  2039: {ppd_combined[2039-1600]:.2f} PPD (target: 2.32)")
print(f"  2100: {ppd_combined[2100-1600]:.2f} PPD (target: 1.9)")

print(f"\n✨ Done! CSV file saved and plot displayed.")
# Out:
# 📈 PROJECTIONS FOR KEY YEARS
# ...
#   Year 1600: 6.00 PPD [Linear (backward)]
#   Year 1650: 5.80 PPD [Linear (backward)]
#   Year 1700: 5.60 PPD [Linear (backward)]
#   Year 1750: 5.40 PPD [Linear (backward)]
#   Year 1800: 5.20 PPD [Linear (backward)]
#   Year 1850: 5.00 PPD [Cubic Spline]
#   Year 1900: 4.74 PPD [Cubic Spline]
#   Year 1950: 4.21 PPD [Cubic Spline]
#   Year 2000: 2.90 PPD [Cubic Spline]
#   Year 2039: 2.32 PPD [Cubic Spline]
#   Year 2050: 2.24 PPD [Linear (forward)]
#   Year 2075: 2.07 PPD [Linear (forward)]
#   Year 2100: 1.90 PPD [Linear (forward)]
#
# ✅ Target verification:
#   1600: 6.00 PPD (target: 6.0)
#   1850: 5.00 PPD (target: 5.0)
#   2039: 2.32 PPD (target: 2.32)
#   2100: 1.90 PPD (target: 1.9)
#
# ✨ Done! CSV file saved and plot displayed.

# %% [markdown]
# STEP 3: READ POPULATION AND PPD AND CREATE STOCK

# %%
#Read population data from file

df_pop = pd.read_csv('population.csv')
df_pop.columns = ['Year', 'Population']
print(df_pop.head())
# Out:
#      Year    Population
# 0  1601.0  8.404315e+06
# 1  1602.0  8.404003e+06
# 2  1603.0  8.403693e+06
# 3  1604.0  8.403389e+06
# 4  1605.0  8.403094e+06

# %%
#Read PPD
df_ppd_raw = pd.read_csv('spain_ppd_projections_1600_2100.csv')
df_ppd = df_ppd_raw.drop('Method', axis=1)
print(df_ppd.head())
# Out:
#    Year  PPD_Projected
# 0  1600          6.000
# 1  1601          5.996
# 2  1602          5.992
# 3  1603          5.988
# 4  1604          5.984

# %%
#Stock calculation
# Merge the dataframes on Year
df_combined = pd.merge(df_pop, df_ppd, on='Year')


df_combined['Product'] = df_combined.iloc[:, 1] / df_combined['PPD_Projected']

# Get just Year and Product
result = df_combined[['Year', 'Product']]
print(result.head())
# Out:
#      Year       Product
# 0  1601.0  1.401654e+06
# 1  1602.0  1.402537e+06
# 2  1603.0  1.403422e+06
# 3  1604.0  1.404310e+06
# 4  1605.0  1.405200e+06

# %%
# reading vertification data from excel file
vertification = pd.read_excel("stock_vertification.xlsx", index_col = None, header = 0, usecols = 'A:B')
print(vertification)
# Out:
#     year  main dwelling
# 0   1950        6224288
# 1   1960        7346037
# 2   1970        9913879
# 3   1981       12827532
# 4   1991       14498010
# 5   2001       14187169
# 6   2011       18083692
# 7   2013       18217300
# 8   2014       18303100
# 9   2015       18346200
# 10  2016       18406100
# 11  2017       18472800
# 12  2018       18535900
# 13  2019       18625700
# 14  2020       18754800

# %%
#Plotting housing stock over time with vertification data
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(result['Year'], result['Product'], linestyle='-', lw = 3, label='Calculated Housing Stock')
plt.plot(vertification['year'], vertification['main dwelling'], '.', label='Stock Vertification', color='navy', markersize=9)
plt.title('Housing Stock Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Dwellings')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# STEP 4: CALCULATE INFLOW AND OUTFLOW WITH DYNAMIC STOCK MODEL

# %%
# Create a time array from 1600 to 2100
t_array = np.arange(1601, 2101)

# Define the lifetime distribution parameters for dwellings
lt_dw = {
    'Type': 'Normal',
    'Mean': np.array([80.0]),
    'StdDev': np.array([15.0]) # Assuming a standard deviation of 15 years for the lifetime of dwellings
}

# Extract ONLY the Product column as a 1D array
product_values = result.iloc[:, 1].values  # Shape: (500,)
#print(product_values)

# Create and run the model
DSM_SPN_dw = DynamicStockModel(t=t_array, s=product_values, lt=lt_dw)
D_all, O_C_all, I_all, ExitFlag = DSM_SPN_dw.compute_stock_driven_model()

print("✅ Model ran successfully!")
print(f"ExitFlag: {ExitFlag}")
# Out:
# ✅ Model ran successfully!
# ExitFlag: 1

# %%
# Creating outflow arrays

O_C_1d = np.sum(O_C_all, axis=1)

# %% [markdown]
# Plotting DSM

# %%
#plotting the results
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.plot(t_array, I_all/1000, label='Inflow', lw=3, color='green')
plt.plot(t_array, O_C_1d/1000, label='Outflow', lw=3, color='red')
plt.title('Dynamic Stock Model Results', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of dwellings built/demolished, thousands', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %%
# plotting after 1900
plt.figure(figsize=(15, 8))
plt.plot(t_array[t_array >= 1900], I_all[t_array >= 1900]/1000, label='Inflow', lw=3, color='green')
plt.plot(t_array[t_array >= 1900], O_C_1d[t_array >= 1900]/1000, label='Outflow', lw=3, color='red')
plt.title('Dynamic Stock Model Results (After 1900)', fontsize=18)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Number of dwellings built/demolished, thousands', fontsize=16)
plt.grid(True)
plt.legend(fontsize=14)
plt.show()

# %%
# Extracting data from the source file into a panda Dataframe
validation_file = "inflow_validation.xlsx"
# This file should be placed in the same directory as this notebook (on the JupyterHub server)

# We read the data and store it in a Dataframe called "data", using the read_excel() panda function
data_raw = pd.read_excel(validation_file, index_col = None, header = 0, usecols = 'D:K')
validation_data = data_raw.iloc[0:79]
#print(validation_data)

# %%
plt.figure(figsize=(10, 5))
plt.plot(t_array[(t_array >= 1900) & (t_array <= 2030)], I_all[(t_array >= 1900) & (t_array <= 2030)], label='Inflow', lw=2, color='green')
plt.plot(validation_data['YEAR'], validation_data['SOURCE1'], '.', label='Inflow Validation source 1')
plt.plot(validation_data['YEAR'], validation_data['SOURCE2'], '.', label='Inflow Validation source 2')
plt.plot(validation_data['YEAR'], validation_data['SOURCE3'], '.', label='Inflow Validation source 3')
plt.plot(validation_data['YEAR'], validation_data['SOURCE4'], '.', label='Inflow Validation source 4')
plt.plot(validation_data['YEAR'], validation_data['SOURCE5'], '.', label='Inflow Validation source 5')
plt.plot(validation_data['YEAR'], validation_data['SOURCE6'], '.', label='Inflow Validation source 6')
plt.plot(validation_data['YEAR'], validation_data['SOURCE7'], '.', label='Inflow Validation source 7')
plt.title('Inflow with Validation data')
plt.xlabel('Year')
plt.grid()
plt.ylabel('Number of new dwellings')
plt.legend()
plt.show()

#can also exclude source 2 and 4, with the most extreme tops

# %% [markdown]
# STEP 5: TYPE SPLIT

# %%
from scipy.interpolate import PchipInterpolator
import matplotlib.pyplot as plt

# raw points for plotting only - from the excel
pct_raw = pd.read_excel("spain_dwelling_types.xlsx", sheet_name="Data", header=2)[["Year", "Apartment / Flat (%)", "Semi-Detached / Terraced (%)", "Detached (%)"]].dropna(subset=["Year"])
pct_raw.columns = ["Year", "pct_apt", "pct_semi", "pct_det"]
pct_raw = pct_raw[pd.to_numeric(pct_raw["Year"], errors="coerce").notna()]
pct_raw["Year"] = pct_raw["Year"].astype(int)
pct_raw[["pct_apt", "pct_semi", "pct_det"]] = pct_raw[["pct_apt", "pct_semi", "pct_det"]].apply(pd.to_numeric, errors="coerce")
pct_raw = pct_raw.dropna()

# curated anchor points

pct_clean = pd.DataFrame({
    "Year":    [1600, 1700, 1800, 1850, 1900, 1910, 1920, 1930, 1940, 1950, 1960, 1970, 1981, 1991, 2001, 2024, 2050, 2075, 2100],
    "pct_apt": [   5,    4,    5,    7,   10,   12,   14,   16,   22,   28,   38,   50,   55,   59,   64,   66,   68,   68,   68],
    "pct_semi":[   5,    6,    8,    8,    8,    9,   10,   11,   12,   13,   14,   15,   17,   19,   21,   21,   19,   18,   17],
    "pct_det": [  90,   90,   87,   85,   80,   79,   76,   72,   66,   58,   52,   42,   30,   23,   19,   15,   16,   16,   16],
})

type_split = result[["Year", "Product"]].copy()

for col in ["pct_apt", "pct_semi", "pct_det"]:
    interp = PchipInterpolator(pct_clean["Year"].values, pct_clean[col].values, extrapolate=False)
    vals = interp(type_split["Year"].values)
    last_val = pct_clean[col].iloc[-1]
    vals = np.where(type_split["Year"].values > pct_clean["Year"].max(), last_val, vals)
    type_split[col] = np.clip(vals, 0, 100)

# renormalise
row_sum = type_split[["pct_apt", "pct_semi", "pct_det"]].sum(axis=1)
for col in ["pct_apt", "pct_semi", "pct_det"]:
    type_split[col] = type_split[col] / row_sum * 100

# calculate stocks
type_split["apt_stock"]  = type_split["Product"] * type_split["pct_apt"]  / 100
type_split["semi_stock"] = type_split["Product"] * type_split["pct_semi"] / 100
type_split["det_stock"]  = type_split["Product"] * type_split["pct_det"]  / 100

type_split = type_split[["Year", "apt_stock", "semi_stock", "det_stock"]]

# ── plot raw excel points vs smoothed curated spline ─────────────────────────
fig, axes = plt.subplots(3, 1, figsize=(12, 10), sharex=True)

cols   = ["pct_apt",   "pct_semi",      "pct_det"]
labels = ["Apartment", "Semi-Detached", "Detached"]
colors = ["steelblue", "darkorange",    "seagreen"]

for ax, col, label, color in zip(axes, cols, labels, colors):
    ax.scatter(pct_raw["Year"], pct_raw[col], color=color, zorder=5, s=20, label="Raw data")
    smoothed_pct = type_split[col.replace("pct_", "") + "_stock"] / type_split[["apt_stock","semi_stock","det_stock"]].sum(axis=1) * 100
    ax.plot(type_split["Year"], smoothed_pct, color=color, linewidth=1.5, label="Smoothed")
    ax.set_ylabel("% Share", fontsize=16)
    ax.set_title(label, fontsize=16)
    ax.legend(fontsize=14)
    ax.grid(True, alpha=0.3)

axes[-1].set_xlabel("Year", fontsize=16)
plt.suptitle("Spain Dwelling Type Split — Raw vs Smoothed", y=1.01, fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# type split plotting

# %%
fig, ax = plt.subplots(figsize=(12, 5))

ax.plot(type_split["Year"], type_split["apt_stock"], lw= 3, label="Apartment / Flat")
ax.plot(type_split["Year"], type_split["semi_stock"], lw= 3, label="Semi-Detached / Terraced")
ax.plot(type_split["Year"], type_split["det_stock"], lw= 3, label="Detached")

ax.set_title("Spain: Dwelling Stock by Type (1601–2024)", fontsize=20)
ax.set_xlabel("Year", fontsize=16)
ax.set_ylabel("Dwellings", fontsize=16)
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f"{x/1e6:.1f}m"))
ax.legend(fontsize = 16)
plt.tight_layout()
plt.show()

# %% [markdown]
# DSM on all different types

# %%
# run dynamic stock model for each dwelling type
lt_dw = {
    'Type': 'Normal',
    'Mean': np.array([80.0]),
    'StdDev': np.array([15.0])
}

results_by_type = {}

for col, label in [("apt_stock", "Apartment"), ("semi_stock", "Semi-Detached"), ("det_stock", "Detached")]:
    stock_values = type_split[col].values
    DSM = DynamicStockModel(t=t_array, s=stock_values, lt=lt_dw)
    D_all, O_C_all, I_all, ExitFlag = DSM.compute_stock_driven_model()
    results_by_type[label] = {
        "D":   D_all,
        "O_C": O_C_all,
        "I":   I_all,
    }
    print(f"✅ {label} — ExitFlag: {ExitFlag}")
# Out:
# ✅ Apartment — ExitFlag: 1

# %%
# Filter years 1900-2100
years_filtered = t_array[(t_array >= 1900) & (t_array <= 2100)]
year_indices = np.where((t_array >= 1900) & (t_array <= 2100))[0]

# Create subplots for each dwelling type
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
fig.suptitle('Inflow and Outflow by Dwelling Type (1900-2100)', fontsize=16)

for ax, (label, data) in zip(axes, results_by_type.items()):
    # Convert 2D O_C to 1D by summing across age dimension
    O_C_1d = np.sum(data["O_C"], axis=1)
    
    # Filter data for years 1900-2100
    O_C_filtered = O_C_1d[year_indices]
    I_filtered = data["I"][year_indices]
    
    # Plot inflow and outflow
    ax.plot(years_filtered, I_filtered/1000, label='Inflow (I) - Construction', linewidth=2, color='green')
    ax.plot(years_filtered, O_C_filtered/1000, label='Outflow (O_C) - Demolition/Conversion', linewidth=2, color='red')
    
    # Customize each subplot
    ax.set_title(f'{label}', fontsize=20)
    ax.set_xlabel('Year', fontsize=16)
    ax.set_ylabel('Number of Dwellings, thousands', fontsize=16)
    ax.legend(fontsize=10)
    ax.grid(True, alpha=0.3)
    ax.set_xlim(1900, 2100)
    
    # Format x-axis to show every 20 years
    ax.set_xticks(np.arange(1900, 2101, 20))
    
    # Add horizontal line at zero for reference
    ax.axhline(y=0, color='black', linestyle='-', linewidth=0.5, alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# STEP 6: MATERIAL INTENSITY, FLOOR AREA AND EMISSIONS INTENSITIES BY MATERIAL

# %%
#average useful floor area by dwelling type (m2):
area_detached = 122.2
area_semi_detached = 112.3
area_apartment = 81.0

#material intensities (kg/m2) by dwelling type
#MultiFamily (MF) corresponds to apartments and SingleFamily (SF) corresponds to detached and semi-detached dwellings

materials = np.array([           'concrete', 'brick',  'wood', 'steel', 'glass', 'plastics', 'aluminium', 'copper'])
MF_material_intensity =  np.array([932.54,    268.75,   9.90,   52.60,   3.10,    1.22,       0.50,        0.18])
SF_material_intensity = np.array([867.16,    181.39,   20.28,  32.45,   2.10,    1.32,       0.49,        0.18])

#emission intensities (kg CO2e/kg material) by material
emission_intensity = np.array([    0.16,       0.28,    1,      1.2,     2.5,     4.1,        5.3,         4.6])

# %%
#material composition of each dwelling type (kg)
detached_materials =  SF_material_intensity * area_detached
semi_detached_materials = SF_material_intensity * area_semi_detached
apartment_materials = MF_material_intensity * area_apartment

materials_overview = pd.DataFrame({
    "Material": materials,
    "Detached (kg)": detached_materials,
    "Semi-Detached (kg)": semi_detached_materials,
    "Apartment (kg)": apartment_materials,
    "Emission intensities (kg CO2e/kg material)": emission_intensity
})

print(materials_overview)
# Out:
#     Material  Detached (kg)  Semi-Detached (kg)  Apartment (kg)  \
# 0   concrete     105966.952           97382.068        75535.74
# 1      brick      22165.858           20370.097        21768.75
# 2       wood       2478.216            2277.444          801.90
# 3      steel       3965.390            3644.135         4260.60
# 4      glass        256.620             235.830          251.10
# 5   plastics        161.304             148.236           98.82
# 6  aluminium         59.878              55.027           40.50
# 7     copper         21.996              20.214           14.58
#
#    Emission intensities (kg CO2e/kg material)
# 0                                        0.16
# 1                                        0.28
# 2                                        1.00
# 3                                        1.20
# 4                                        2.50
# 5                                        4.10
# 6                                        5.30
# ...

# %%
plt.bar(x=['Multi-Family', 'Single-Family'], height = [MF_material_intensity[0], SF_material_intensity[0]], label='Concrete', color='dimgrey')
plt.bar(x=['Multi-Family', 'Single-Family'], height = [MF_material_intensity[1], SF_material_intensity[1]], label='Brick', color='sienna', bottom=[MF_material_intensity[0], SF_material_intensity[0]])
plt.bar(x=['Multi-Family', 'Single-Family'], height = [MF_material_intensity[2], SF_material_intensity[2]], label='Wood', color='peru', bottom=[MF_material_intensity[0]+MF_material_intensity[1], SF_material_intensity[0]+SF_material_intensity[1]])
plt.bar(x=['Multi-Family', 'Single-Family'], height = [MF_material_intensity[3], SF_material_intensity[3]], label='Steel', color='lightsteelblue', bottom=[MF_material_intensity[0]+MF_material_intensity[1]+MF_material_intensity[2], SF_material_intensity[0]+SF_material_intensity[1]+SF_material_intensity[2]]) 
plt.bar(x=['Multi-Family', 'Single-Family'], height = [MF_material_intensity[4], SF_material_intensity[4]], label='Glass', color='turquoise', bottom=[MF_material_intensity[0]+MF_material_intensity[1]+MF_material_intensity[2]+MF_material_intensity[3], SF_material_intensity[0]+SF_material_intensity[1]+SF_material_intensity[2]+SF_material_intensity[3]])
plt.bar(x=['Multi-Family', 'Single-Family'], height = [MF_material_intensity[5], SF_material_intensity[5]], label='Plastics', color='lightcoral', bottom=[MF_material_intensity[0]+MF_material_intensity[1]+MF_material_intensity[2]+MF_material_intensity[3]+MF_material_intensity[4], SF_material_intensity[0]+SF_material_intensity[1]+SF_material_intensity[2]+SF_material_intensity[3]+SF_material_intensity[4]])
plt.bar(x=['Multi-Family', 'Single-Family'], height = [MF_material_intensity[6], SF_material_intensity[6]], label='Aluminium', color='gray', bottom=[MF_material_intensity[0]+MF_material_intensity[1]+MF_material_intensity[2]+MF_material_intensity[3]+MF_material_intensity[4]+MF_material_intensity[5], SF_material_intensity[0]+SF_material_intensity[1]+SF_material_intensity[2]+SF_material_intensity[3]+SF_material_intensity[4]+SF_material_intensity[5]])
plt.bar(x=['Multi-Family', 'Single-Family'], height = [MF_material_intensity[7], SF_material_intensity[7]], label='Copper', color='firebrick', bottom=[MF_material_intensity[0]+MF_material_intensity[1]+MF_material_intensity[2]+MF_material_intensity[3]+MF_material_intensity[4]+MF_material_intensity[5]+MF_material_intensity[6], SF_material_intensity[0]+SF_material_intensity[1]+SF_material_intensity[2]+SF_material_intensity[3]+SF_material_intensity[4]+SF_material_intensity[5]+SF_material_intensity[6]])
plt.xlabel('Dwelling Type')
plt.ylabel('Material Intensity (kg/m²)')
plt.title('Material Intensity by Dwelling Type')
plt.legend()
plt.show()

# %%
plt.bar(x=['Detached', 'Semi-detached', 'Apartment'], height=[detached_materials[0], semi_detached_materials[0], apartment_materials[0]], label='Concrete', color='dimgrey')
plt.bar(x=['Detached', 'Semi-detached', 'Apartment'], height=[detached_materials[1], semi_detached_materials[1], apartment_materials[1]], label='Brick', color='sienna', bottom=[detached_materials[0], semi_detached_materials[0], apartment_materials[0]])
plt.bar(x=['Detached', 'Semi-detached', 'Apartment'], height=[detached_materials[2], semi_detached_materials[2], apartment_materials[2]], label='Wood', color='peru', bottom=[detached_materials[0]+detached_materials[1], semi_detached_materials[0]+semi_detached_materials[1], apartment_materials[0]+apartment_materials[1]])
plt.bar(x=['Detached', 'Semi-detached', 'Apartment'], height=[detached_materials[3], semi_detached_materials[3], apartment_materials[3]], label='Steel', color='lightsteelblue', bottom=[detached_materials[0]+detached_materials[1]+detached_materials[2], semi_detached_materials[0]+semi_detached_materials[1]+semi_detached_materials[2], apartment_materials[0]+apartment_materials[1]+apartment_materials[2]])
plt.bar(x=['Detached', 'Semi-detached', 'Apartment'], height=[detached_materials[4], semi_detached_materials[4], apartment_materials[4]], label='Glass', color='turquoise', bottom=[detached_materials[0]+detached_materials[1]+detached_materials[2]+detached_materials[3], semi_detached_materials[0]+semi_detached_materials[1]+semi_detached_materials[2]+semi_detached_materials[3], apartment_materials[0]+apartment_materials[1]+apartment_materials[2]+apartment_materials[3]])
plt.bar(x=['Detached', 'Semi-detached', 'Apartment'], height=[detached_materials[5], semi_detached_materials[5], apartment_materials[5]], label='Plastics', color='lightcoral', bottom=[detached_materials[0]+detached_materials[1]+detached_materials[2]+detached_materials[3]+detached_materials[4], semi_detached_materials[0]+semi_detached_materials[1]+semi_detached_materials[2]+semi_detached_materials[3]+semi_detached_materials[4], apartment_materials[0]+apartment_materials[1]+apartment_materials[2]+apartment_materials[3]+apartment_materials[4]])
plt.bar(x=['Detached', 'Semi-detached', 'Apartment'], height=[detached_materials[6], semi_detached_materials[6], apartment_materials[6]], label='Aluminium', color='gray', bottom=[detached_materials[0]+detached_materials[1]+detached_materials[2]+detached_materials[3]+detached_materials[4]+detached_materials[5], semi_detached_materials[0]+semi_detached_materials[1]+semi_detached_materials[2]+semi_detached_materials[3]+semi_detached_materials[4]+semi_detached_materials[5], apartment_materials[0]+apartment_materials[1]+apartment_materials[2]+apartment_materials[3]+apartment_materials[4]+apartment_materials[5]])
plt.bar(x=['Detached', 'Semi-detached', 'Apartment'], height=[detached_materials[7], semi_detached_materials[7], apartment_materials[7]], label='Copper', color='firebrick', bottom=[detached_materials[0]+detached_materials[1]+detached_materials[2]+detached_materials[3]+detached_materials[4]+detached_materials[5]+detached_materials[6], semi_detached_materials[0]+semi_detached_materials[1]+semi_detached_materials[2]+semi_detached_materials[3]+semi_detached_materials[4]+semi_detached_materials[5]+semi_detached_materials[6], apartment_materials[0]+apartment_materials[1]+apartment_materials[2]+apartment_materials[3]+apartment_materials[4]+apartment_materials[5]+apartment_materials[6]])
plt.ylabel('Material Mass (kg)')
plt.title('Material Composition by Dwelling Type')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
plt.bar(x=['Detached', 'Semi-detached', 'Apartment'], height=[detached_materials[2], semi_detached_materials[2], apartment_materials[2]], label='Wood', color='peru')
plt.bar(x=['Detached', 'Semi-detached', 'Apartment'], height=[detached_materials[3], semi_detached_materials[3], apartment_materials[3]], label='Steel', color='lightsteelblue', bottom=[detached_materials[2], semi_detached_materials[2], apartment_materials[2]])
plt.bar(x=['Detached', 'Semi-detached', 'Apartment'], height=[detached_materials[4], semi_detached_materials[4], apartment_materials[4]], label='Glass', color='turquoise', bottom=[detached_materials[2]+detached_materials[3], semi_detached_materials[2]+semi_detached_materials[3], apartment_materials[2]+apartment_materials[3]])
plt.bar(x=['Detached', 'Semi-detached', 'Apartment'], height=[detached_materials[5], semi_detached_materials[5], apartment_materials[5]], label='Plastics', color='lightcoral', bottom=[detached_materials[2]+detached_materials[3]+detached_materials[4], semi_detached_materials[2]+semi_detached_materials[3]+semi_detached_materials[4], apartment_materials[2]+apartment_materials[3]+apartment_materials[4]])
plt.bar(x=['Detached', 'Semi-detached', 'Apartment'], height=[detached_materials[6], semi_detached_materials[6], apartment_materials[6]], label='Aluminium', color='gray', bottom=[detached_materials[2]+detached_materials[3]+detached_materials[4]+detached_materials[5], semi_detached_materials[2]+semi_detached_materials[3]+semi_detached_materials[4]+semi_detached_materials[5], apartment_materials[2]+apartment_materials[3]+apartment_materials[4]+apartment_materials[5]])
plt.bar(x=['Detached', 'Semi-detached', 'Apartment'], height=[detached_materials[7], semi_detached_materials[7], apartment_materials[7]], label='Copper', color='firebrick', bottom=[detached_materials[2]+detached_materials[3]+detached_materials[4]+detached_materials[5]+detached_materials[6], semi_detached_materials[2]+semi_detached_materials[3]+semi_detached_materials[4]+semi_detached_materials[5]+semi_detached_materials[6], apartment_materials[2]+apartment_materials[3]+apartment_materials[4]+apartment_materials[5]+apartment_materials[6]])
plt.ylabel('Material Mass (kg)')
plt.title('Detailed Material Composition by Dwelling Type')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# Integrating material with dynamic stock model

# %%
# material inflow = new dwellings built each year * floor area * material intensity (kg)
material_inflows = {}

for label, area, intensity in [
    ("Apartment",     area_apartment,     MF_material_intensity),
    ("Semi-Detached", area_semi_detached, SF_material_intensity),
    ("Detached",      area_detached,      SF_material_intensity),
]:
    # inflow in dwellings, multiply by area and intensity to get kg per material
    I = results_by_type[label]["I"]  # shape: (500,)
    # result: (500 years x 8 materials)
    material_inflows[label] = pd.DataFrame(
        np.outer(I, area * intensity),
        columns=materials,
        index=t_array
    )

print(material_inflows["Apartment"].head())
# Out:
#           concrete         brick          wood         steel         glass  \
# 1601  5.273460e+09  1.519766e+09  5.598393e+07  2.974500e+08  1.753032e+07
# 1602 -1.678688e+07 -4.837834e+06 -1.782123e+05 -9.468654e+05 -5.580385e+04
# 1603 -1.661710e+07 -4.788906e+06 -1.764099e+05 -9.372892e+05 -5.523948e+04
# 1604 -1.644493e+07 -4.739288e+06 -1.745821e+05 -9.275778e+05 -5.466713e+04
# 1605 -1.627038e+07 -4.688982e+06 -1.727290e+05 -9.177320e+05 -5.408687e+04
#
#           plastics     aluminium        copper
# 1601  6.899030e+06  2.827471e+06  1.017890e+06
# 1602 -2.196152e+04 -9.000622e+03 -3.240224e+03
# 1603 -2.173941e+04 -8.909593e+03 -3.207454e+03
# 1604 -2.151416e+04 -8.817279e+03 -3.174220e+03
# 1605 -2.128580e+04 -8.723688e+03 -3.140528e+03

# %% [markdown]
# Plotting material use of inflow

# %%
fig, axes = plt.subplots(4, 2, figsize=(14, 16), sharex=True)
axes = axes.flatten()

for i, mat in enumerate(materials):
    ax = axes[i]
    for label, color in [("Apartment", "steelblue"), ("Semi-Detached", "darkorange"), ("Detached", "seagreen")]:
        df = material_inflows[label]
        mask = (df.index >= 1900) & (df.index <= 2100)
        ax.plot(df.index[mask], df.loc[mask, mat] / 1e9, lw = 3, label=label, color=color)
    ax.set_title(mat, fontsize=16)
    ax.set_ylabel("Mt", fontsize=16)
    ax.grid(True, alpha=0.3)
    ax.legend(fontsize=14)

axes[-1].set_xlabel("Year", fontsize=16)
plt.suptitle("Material Inflows by Dwelling Type (1900–2100)", y=1.01, fontsize=20)
plt.tight_layout()
plt.show()

# %%
# plotting material use this way at request of seminar 2
time = np.arange(1900, 2101)
plt.figure(figsize=(15,8))
plt.stackplot(time, material_inflows["Apartment"]['concrete'].loc[1900:2100] / 1e9, material_inflows["Apartment"]['brick'].loc[1900:2100] / 1e9, material_inflows["Apartment"]['wood'].loc[1900:2100] / 1e9, material_inflows["Apartment"]['steel'].loc[1900:2100] / 1e9, material_inflows["Apartment"]['glass'].loc[1900:2100] / 1e9, labels=['Concrete', 'Brick', 'Wood', 'Steel', 'Glass'], colors=['dimgrey', 'sienna', 'peru', 'silver', 'turquoise'])
plt.title('Material Use in Apartment Construction by source (1900-2100)', fontsize=20)
plt.xticks(np.arange(1900, 2101, 10))
plt.xlabel('Year', fontsize=16)
plt.ylabel('Material Use (Gt)', fontsize=16)
plt.legend(fontsize=14)
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# STEP 7: CALCULATE EMISSIONS

# %%
# APARTMENTS
concrete_use_apartment = np.array(material_inflows["Apartment"]['concrete'].loc[1900:2100])
concrete_emissions_apartment = concrete_use_apartment * emission_intensity[0]

brick_use_apartment = np.array(material_inflows["Apartment"]['brick'].loc[1900:2100])
brick_emissions_apartment = brick_use_apartment * emission_intensity[1]

wood_use_apartment = np.array(material_inflows["Apartment"]['wood'].loc[1900:2100])
wood_emissions_apartment = wood_use_apartment * emission_intensity[2]

steel_use_apartment = np.array(material_inflows["Apartment"]['steel'].loc[1900:2100])
steel_emissions_apartment = steel_use_apartment * emission_intensity[3]

glass_use_apartment = np.array(material_inflows["Apartment"]['glass'].loc[1900:2100])
glass_emissions_apartment = glass_use_apartment * emission_intensity[4]

total_emissions_apartment = concrete_emissions_apartment + brick_emissions_apartment + wood_emissions_apartment + steel_emissions_apartment + glass_emissions_apartment

# SEMI-DETACHED
concrete_use_semi = np.array(material_inflows["Semi-Detached"]['concrete'].loc[1900:2100])
concrete_emissions_semi = concrete_use_semi * emission_intensity[0]

brick_use_semi = np.array(material_inflows["Semi-Detached"]['brick'].loc[1900:2100])
brick_emissions_semi = brick_use_semi * emission_intensity[1]

wood_use_semi = np.array(material_inflows["Semi-Detached"]['wood'].loc[1900:2100])
wood_emissions_semi = wood_use_semi * emission_intensity[2]

steel_use_semi = np.array(material_inflows["Semi-Detached"]['steel'].loc[1900:2100])
steel_emissions_semi = steel_use_semi * emission_intensity[3]

glass_use_semi = np.array(material_inflows["Semi-Detached"]['glass'].loc[1900:2100])
glass_emissions_semi = glass_use_semi * emission_intensity[4]

total_emissions_semi = concrete_emissions_semi + brick_emissions_semi + wood_emissions_semi + steel_emissions_semi + glass_emissions_semi

# DETACHED
concrete_use_detached = np.array(material_inflows["Detached"]['concrete'].loc[1900:2100])
concrete_emissions_detached = concrete_use_detached * emission_intensity[0]

brick_use_detached = np.array(material_inflows["Detached"]['brick'].loc[1900:2100])
brick_emissions_detached = brick_use_detached * emission_intensity[1]

wood_use_detached = np.array(material_inflows["Detached"]['wood'].loc[1900:2100])
wood_emissions_detached = wood_use_detached * emission_intensity[2]

steel_use_detached = np.array(material_inflows["Detached"]['steel'].loc[1900:2100])
steel_emissions_detached = steel_use_detached * emission_intensity[3]

glass_use_detached = np.array(material_inflows["Detached"]['glass'].loc[1900:2100])
glass_emissions_detached = glass_use_detached * emission_intensity[4]

total_emissions_detached = concrete_emissions_detached + brick_emissions_detached + wood_emissions_detached + steel_emissions_detached + glass_emissions_detached

# %%
#PLOT APARTMENT EMISSIONS BY SOURCE

plt.figure(figsize=(15,8))
plt.stackplot(time, concrete_emissions_apartment/ 1e9, brick_emissions_apartment/ 1e9, wood_emissions_apartment/ 1e9, steel_emissions_apartment/ 1e9, glass_emissions_apartment/ 1e9, labels=['Concrete', 'Brick', 'Wood', 'Steel', 'Glass'], colors=['dimgrey', 'sienna', 'peru', 'silver', 'turquoise'])
plt.title('Emissions from Apartment Construction by source (1900-2100)', fontsize=20)
plt.xticks(np.arange(1900, 2101, 10))
plt.xlabel('Year', fontsize=16)
plt.ylabel('Emissions (Gt CO2e)', fontsize=16)
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# PLOT SEMI-DETACHED EMISSIONS BY SOURCE

plt.figure(figsize=(15,8))
plt.stackplot(time, concrete_emissions_semi/ 1e9, brick_emissions_semi/ 1e9, wood_emissions_semi/ 1e9, steel_emissions_semi/ 1e9, glass_emissions_semi/ 1e9, labels=['Concrete', 'Brick', 'Wood', 'Steel', 'Glass'], colors=['dimgrey', 'sienna', 'peru', 'silver', 'turquoise'])
plt.title('Emissions from Semi-Detached Construction by source (1900-2100)', fontsize=20)
plt.xticks(np.arange(1900, 2101, 10))
plt.xlabel('Year', fontsize=16)
plt.ylabel('Emissions (Gt CO2e)', fontsize=16)
plt.legend(fontsize = 14)
plt.grid(True, alpha=0.3)
plt.show()

# %%
#PLOT DETACHED EMISSIONS BY SOURCE

plt.figure(figsize=(15,8))
plt.stackplot(time, concrete_emissions_detached/ 1e9, brick_emissions_detached/ 1e9, wood_emissions_detached/ 1e9, steel_emissions_detached/ 1e9, glass_emissions_detached/ 1e9, labels=['Concrete', 'Brick', 'Wood', 'Steel', 'Glass'], colors=['dimgrey', 'sienna', 'peru', 'silver', 'turquoise'])
plt.title('Emissions from Detached Construction by source (1900-2100)', fontsize=20)
plt.xticks(np.arange(1900, 2101, 10))
plt.xlabel('Year', fontsize=16)
plt.ylabel('Emissions (Gt CO2e)', fontsize=16)
plt.legend(fontsize=14)
plt.grid(True, alpha=0.3)
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 6), sharey=True)

# Common settings
labels = ['Concrete', 'Brick', 'Wood', 'Steel', 'Glass']
colors = ['dimgrey', 'sienna', 'peru', 'silver', 'turquoise']

# --- Plot 1: Apartment ---
axs[0].stackplot(
    time,
    concrete_emissions_apartment / 1e9,
    brick_emissions_apartment / 1e9,
    wood_emissions_apartment / 1e9,
    steel_emissions_apartment / 1e9,
    glass_emissions_apartment / 1e9,
    labels=labels,
    colors=colors
)
axs[0].set_title('Apartment', fontsize = 16)
axs[0].set_xlabel('Year', fontsize = 16)
axs[0].set_ylabel('Emissions (Gt CO2e)', fontsize = 16)
axs[0].grid(True, alpha=0.3)

# --- Plot 2: Semi-detached ---
axs[1].stackplot(
    time,
    concrete_emissions_semi / 1e9,
    brick_emissions_semi / 1e9,
    wood_emissions_semi / 1e9,
    steel_emissions_semi / 1e9,
    glass_emissions_semi / 1e9,
    labels=labels,
    colors=colors
)
axs[1].set_title('Semi-detached', fontsize = 16)
axs[1].set_xlabel('Year', fontsize = 16)
axs[1].grid(True, alpha=0.3)

# --- Plot 3: Detached ---
axs[2].stackplot(
    time,
    concrete_emissions_detached / 1e9,
    brick_emissions_detached / 1e9,
    wood_emissions_detached / 1e9,
    steel_emissions_detached / 1e9,
    glass_emissions_detached / 1e9,
    labels=labels,
    colors=colors
)
axs[2].set_title('Detached', fontsize = 16)
axs[2].set_xlabel('Year', fontsize = 16)
axs[2].grid(True, alpha=0.3)

# X-ticks (apply to all)
for ax in axs:
    ax.set_xticks(np.arange(1900, 2101, 20))

# Single legend (cleaner than 3 separate ones)
fig.legend(labels, fontsize=16)

# Overall title
fig.suptitle('Emissions from Construction by Material (1900–2100)', fontsize=20)

plt.tight_layout(rect=[0, 0, 1, 1])
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.plot(time, total_emissions_apartment/ 1e9, lw = 3, label='Apartment', color='steelblue')
plt.plot(time, total_emissions_semi/ 1e9, lw = 3, label='Semi-Detached', color='darkorange')
plt.plot(time, total_emissions_detached/ 1e9, lw = 3, label='Detached', color='seagreen')
plt.title('Total Emissions from Construction by Dwelling Type (1900-2100)', fontsize=20)
plt.xticks(np.arange(1900, 2101, 10))
plt.xlabel('Year', fontsize=16)
plt.ylabel('Emissions (Gt CO2e)', fontsize=16)
plt.legend(fontsize=14)
plt.grid(True, alpha=0.3)
plt.show()

# %%
total_concrete_emissions = concrete_emissions_apartment + concrete_emissions_semi + concrete_emissions_detached
total_brick_emissions = brick_emissions_apartment + brick_emissions_semi + brick_emissions_detached
total_wood_emissions = wood_emissions_apartment + wood_emissions_semi + wood_emissions_detached
total_steel_emissions = steel_emissions_apartment + steel_emissions_semi + steel_emissions_detached
total_glass_emissions = glass_emissions_apartment + glass_emissions_semi + glass_emissions_detached

plt.figure(figsize=(15,8))
plt.stackplot(time, total_concrete_emissions, total_brick_emissions, total_wood_emissions, total_steel_emissions, total_glass_emissions, labels=['Concrete', 'Brick', 'Wood', 'Steel', 'Glass'], colors=['dimgrey', 'sienna', 'peru', 'silver', 'turquoise'])
plt.title('Total Emissions from Construction by Source (1900-2100)', fontsize=20)
plt.xticks(np.arange(1900, 2101, 10))
plt.xlabel('Year', fontsize=16)
plt.ylabel('Emissions (kg CO2e)', fontsize=16)
plt.legend(fontsize=14)
plt.grid(True, alpha=0.3)
plt.show()
