# %%
print('mårna')
# Out:
# mårna

# %% [markdown]
# Goal: fin CO2-emissions from spanish building stock
#
# CO2-emissions = CO2-intensities per material * masses of each material
#
# find the masses of different materials in the total stock, categorized by dwelling type and cohort...

# %%
#Quick maths
a=1+1
print(a)
print('bøngo')
# Out:
# 2
# bøngo
